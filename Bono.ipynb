# %%
import numpy as np

#def fabricar_matriz(filas, columnas):
#    M = []
#    for i in range(filas):
#        fila = []
#        for j in range(columnas):
#            fila.append(list(np.random.random_sample(size = 3)))
#        M.append(fila)
#    return M



def convolucion_imagen(imagen, convolucion):

    def suma(matriz):
        filas = len(matriz)
        columnas = len(matriz[0])
        suma = 0
        for i in range(filas):
            for j in range(columnas):
                suma = suma + matriz[i][j]
        return suma


    filas = len(imagen)
    columnas = len(imagen[0])
    suma_convolucion = suma(convolucion)
    lista = []


    if(suma_convolucion == 0):
        suma_convolucion = 1 # Si la suma de los elementos de la matriz 3x3 es cero, no se tiene que hacer division por la suma de los elementos de la matriz. No hacer division es equivalente a dividir por 1

    if(filas != 1 and columnas !=1 ):
        for i in range(filas):
            fila = []
            for j in range(columnas):
                if( (i != 0 and j != 0) and (i != filas-1 and j != columnas-1) ): # Fuera de los bordes   
                    pixel_r =  imagen[i-1][j-1][0]*convolucion[0][0] + imagen[i-1][j][0]*convolucion[0][1] + imagen[i-1][j+1][0]*convolucion[0][2] + imagen[i][j-1][0]*convolucion[1][0] + imagen[i][j][0]*convolucion[1][1] + imagen[i][j+1][0]*convolucion[1][2] + imagen[i+1][j-1][0]*convolucion[2][0] + imagen[i+1][j][0]*convolucion[2][1] + imagen[i+1][j+1][0]*convolucion[2][2]
                    pixel_g =  imagen[i-1][j-1][1]*convolucion[0][0] + imagen[i-1][j][1]*convolucion[0][1] + imagen[i-1][j+1][1]*convolucion[0][2] + imagen[i][j-1][1]*convolucion[1][0] + imagen[i][j][1]*convolucion[1][1] + imagen[i][j+1][1]*convolucion[1][2] + imagen[i+1][j-1][1]*convolucion[2][0] + imagen[i+1][j][1]*convolucion[2][1] + imagen[i+1][j+1][1]*convolucion[2][2]
                    pixel_b =  imagen[i-1][j-1][2]*convolucion[0][0] + imagen[i-1][j][2]*convolucion[0][1] + imagen[i-1][j+1][2]*convolucion[0][2] + imagen[i][j-1][2]*convolucion[1][0] + imagen[i][j][2]*convolucion[1][1] + imagen[i][j+1][2]*convolucion[1][2] + imagen[i+1][j-1][2]*convolucion[2][0] + imagen[i+1][j][2]*convolucion[2][1] + imagen[i+1][j+1][2]*convolucion[2][2]
                    fila.append([pixel_r/suma_convolucion, pixel_g/suma_convolucion, pixel_b/suma_convolucion])
                elif( i == 0 and j != 0 and j!= columnas-1): #Borde superior, no esquinas
                    pixel_r =  imagen[i][j-1][0]*convolucion[1][0] + imagen[i][j][0]*convolucion[1][1] + imagen[i][j+1][0]*convolucion[1][2] + imagen[i+1][j-1][0]*convolucion[2][0] + imagen[i+1][j][0]*convolucion[2][1] + imagen[i+1][j+1][0]*convolucion[2][2]
                    pixel_g =  imagen[i][j-1][1]*convolucion[1][0] + imagen[i][j][1]*convolucion[1][1] + imagen[i][j+1][1]*convolucion[1][2] + imagen[i+1][j-1][1]*convolucion[2][0] + imagen[i+1][j][1]*convolucion[2][1] + imagen[i+1][j+1][1]*convolucion[2][2]
                    pixel_b =  imagen[i][j-1][2]*convolucion[1][0] + imagen[i][j][2]*convolucion[1][1] + imagen[i][j+1][2]*convolucion[1][2] + imagen[i+1][j-1][2]*convolucion[2][0] + imagen[i+1][j][2]*convolucion[2][1] + imagen[i+1][j+1][2]*convolucion[2][2]
                    fila.append([pixel_r/suma_convolucion, pixel_g/suma_convolucion, pixel_b/suma_convolucion])
                elif( i == filas-1 and j != 0 and j!= columnas-1): #Borde inferior, no esquinas
                    pixel_r =  imagen[i-1][j-1][0]*convolucion[0][0] + imagen[i-1][j][0]*convolucion[0][1] + imagen[i-1][j+1][0]*convolucion[0][2] + imagen[i][j-1][0]*convolucion[1][0] + imagen[i][j][0]*convolucion[1][1] + imagen[i][j+1][0]*convolucion[1][2]
                    pixel_g =  imagen[i-1][j-1][1]*convolucion[0][0] + imagen[i-1][j][1]*convolucion[0][1] + imagen[i-1][j+1][1]*convolucion[0][2] + imagen[i][j-1][1]*convolucion[1][0] + imagen[i][j][1]*convolucion[1][1] + imagen[i][j+1][1]*convolucion[1][2] 
                    pixel_b =  imagen[i-1][j-1][2]*convolucion[0][0] + imagen[i-1][j][2]*convolucion[0][1] + imagen[i-1][j+1][2]*convolucion[0][2] + imagen[i][j-1][2]*convolucion[1][0] + imagen[i][j][2]*convolucion[1][1] + imagen[i][j+1][2]*convolucion[1][2] 
                    fila.append([pixel_r/suma_convolucion, pixel_g/suma_convolucion, pixel_b/suma_convolucion])
                elif( j == 0 and i!=0 and i!= filas-1): # Borde izquierdo, no esquinas  
                    pixel_r =  imagen[i-1][j][0]*convolucion[0][1] + imagen[i-1][j+1][0]*convolucion[0][2]  + imagen[i][j][0]*convolucion[1][1] + imagen[i][j+1][0]*convolucion[1][2] + imagen[i+1][j][0]*convolucion[2][1] + imagen[i+1][j+1][0]*convolucion[2][2]
                    pixel_g =  imagen[i-1][j][1]*convolucion[0][1] + imagen[i-1][j+1][1]*convolucion[0][2] + imagen[i][j][1]*convolucion[1][1] + imagen[i][j+1][1]*convolucion[1][2]  + imagen[i+1][j][1]*convolucion[2][1] + imagen[i+1][j+1][1]*convolucion[2][2]
                    pixel_b =  imagen[i-1][j][2]*convolucion[0][1] + imagen[i-1][j+1][2]*convolucion[0][2]  + imagen[i][j][2]*convolucion[1][1] + imagen[i][j+1][2]*convolucion[1][2] + imagen[i+1][j][2]*convolucion[2][1] + imagen[i+1][j+1][2]*convolucion[2][2]
                    fila.append([pixel_r/suma_convolucion, pixel_g/suma_convolucion, pixel_b/suma_convolucion])
                elif( j == columnas-1 and i!=0 and i!= filas-1): # Borde derecho, no esquinas  
                    pixel_r =  imagen[i-1][j-1][0]*convolucion[0][0] + imagen[i-1][j][0]*convolucion[0][1] + imagen[i][j-1][0]*convolucion[1][0] + imagen[i][j][0]*convolucion[1][1] + imagen[i+1][j-1][0]*convolucion[2][0] + imagen[i+1][j][0]*convolucion[2][1]
                    pixel_g =  imagen[i-1][j-1][1]*convolucion[0][0] + imagen[i-1][j][1]*convolucion[0][1] + imagen[i][j-1][1]*convolucion[1][0] + imagen[i][j][1]*convolucion[1][1] + imagen[i+1][j-1][1]*convolucion[2][0] + imagen[i+1][j][1]*convolucion[2][1] 
                    pixel_b =  imagen[i-1][j-1][2]*convolucion[0][0] + imagen[i-1][j][2]*convolucion[0][1] + imagen[i][j-1][2]*convolucion[1][0] + imagen[i][j][2]*convolucion[1][1] + imagen[i+1][j-1][2]*convolucion[2][0] + imagen[i+1][j][2]*convolucion[2][1] 
                    fila.append([pixel_r/suma_convolucion, pixel_g/suma_convolucion, pixel_b/suma_convolucion])
                elif( i == 0 and j == 0): # Esquina superior izquierda
                    pixel_r =  imagen[i][j][0]*convolucion[1][1] + imagen[i][j+1][0]*convolucion[1][2] + imagen[i+1][j][0]*convolucion[2][1] + imagen[i+1][j+1][0]*convolucion[2][2]
                    pixel_g =  imagen[i][j][1]*convolucion[1][1] + imagen[i][j+1][1]*convolucion[1][2] + imagen[i+1][j][1]*convolucion[2][1] + imagen[i+1][j+1][1]*convolucion[2][2]
                    pixel_b =  imagen[i][j][2]*convolucion[1][1] + imagen[i][j+1][2]*convolucion[1][2] + imagen[i+1][j][2]*convolucion[2][1] + imagen[i+1][j+1][2]*convolucion[2][2]
                    fila.append([pixel_r/suma_convolucion, pixel_g/suma_convolucion, pixel_b/suma_convolucion])
                elif( i == 0 and j == columnas-1): # Esquina superior derecha
                    pixel_r =  imagen[i][j-1][0]*convolucion[1][0] + imagen[i][j][0]*convolucion[1][1] + imagen[i+1][j-1][0]*convolucion[2][0] + imagen[i+1][j][0]*convolucion[2][1]
                    pixel_g =  imagen[i][j-1][1]*convolucion[1][0] + imagen[i][j][1]*convolucion[1][1] + imagen[i+1][j-1][1]*convolucion[2][0] + imagen[i+1][j][1]*convolucion[2][1]
                    pixel_b =  imagen[i][j-1][2]*convolucion[1][0] + imagen[i][j][2]*convolucion[1][1] + imagen[i+1][j-1][2]*convolucion[2][0] + imagen[i+1][j][2]*convolucion[2][1]
                    fila.append([pixel_r/suma_convolucion, pixel_g/suma_convolucion, pixel_b/suma_convolucion])
                elif( i == filas-1 and j == 0 ): # Esquina inferior izquierda   
                    pixel_r =  imagen[i-1][j][0]*convolucion[0][1] + imagen[i-1][j+1][0]*convolucion[0][2] + imagen[i][j][0]*convolucion[1][1] + imagen[i][j+1][0]*convolucion[1][2]
                    pixel_g =  imagen[i-1][j][1]*convolucion[0][1] + imagen[i-1][j+1][1]*convolucion[0][2] + imagen[i][j][1]*convolucion[1][1] + imagen[i][j+1][1]*convolucion[1][2]
                    pixel_b =  imagen[i-1][j][2]*convolucion[0][1] + imagen[i-1][j+1][2]*convolucion[0][2] + imagen[i][j][2]*convolucion[1][1] + imagen[i][j+1][2]*convolucion[1][2]
                    fila.append([pixel_r/suma_convolucion, pixel_g/suma_convolucion, pixel_b/suma_convolucion])
                elif( i == filas-1 and j == columnas-1 ): # Esquina inferior derecha
                    pixel_r =  imagen[i-1][j-1][0]*convolucion[0][0] + imagen[i-1][j][0]*convolucion[0][1] + imagen[i][j-1][0]*convolucion[1][0] + imagen[i][j][0]*convolucion[1][1]
                    pixel_g =  imagen[i-1][j-1][1]*convolucion[0][0] + imagen[i-1][j][1]*convolucion[0][1] + imagen[i][j-1][1]*convolucion[1][0] + imagen[i][j][1]*convolucion[1][1]
                    pixel_b =  imagen[i-1][j-1][2]*convolucion[0][0] + imagen[i-1][j][2]*convolucion[0][1] + imagen[i][j-1][2]*convolucion[1][0] + imagen[i][j][2]*convolucion[1][1]
                    fila.append([pixel_r/suma_convolucion, pixel_g/suma_convolucion, pixel_b/suma_convolucion])
            lista.append(fila)

    elif(filas == 1 and columnas != 1):

        for i in range(filas):
            fila = []
            for j in range(columnas):
                if( i == 0 and j != 0 and j!= columnas-1): #Borde superior, no esquinas
                            pixel_r =  imagen[i][j-1][0]*convolucion[1][0] + imagen[i][j][0]*convolucion[1][1] + imagen[i][j+1][0]*convolucion[1][2] 
                            pixel_g =  imagen[i][j-1][1]*convolucion[1][0] + imagen[i][j][1]*convolucion[1][1] + imagen[i][j+1][1]*convolucion[1][2] 
                            pixel_b =  imagen[i][j-1][2]*convolucion[1][0] + imagen[i][j][2]*convolucion[1][1] + imagen[i][j+1][2]*convolucion[1][2] 
                            fila.append([pixel_r/suma_convolucion, pixel_g/suma_convolucion, pixel_b/suma_convolucion])
                elif( i == 0 and j == 0): # Esquina superior izquierda
                            pixel_r =  imagen[i][j][0]*convolucion[1][1] + imagen[i][j+1][0]*convolucion[1][2]
                            pixel_g =  imagen[i][j][1]*convolucion[1][1] + imagen[i][j+1][1]*convolucion[1][2]
                            pixel_b =  imagen[i][j][2]*convolucion[1][1] + imagen[i][j+1][2]*convolucion[1][2]
                            fila.append([pixel_r/suma_convolucion, pixel_g/suma_convolucion, pixel_b/suma_convolucion])
                elif( i == 0 and j == columnas-1): # Esquina superior derecha
                            pixel_r =  imagen[i][j-1][0]*convolucion[1][0] + imagen[i][j][0]*convolucion[1][1]
                            pixel_g =  imagen[i][j-1][1]*convolucion[1][0] + imagen[i][j][1]*convolucion[1][1]
                            pixel_b =  imagen[i][j-1][2]*convolucion[1][0] + imagen[i][j][2]*convolucion[1][1]
                            fila.append([pixel_r/suma_convolucion, pixel_g/suma_convolucion, pixel_b/suma_convolucion])
            lista.append(fila)

    elif(filas != 1 and columnas == 1):

        for i in range(filas):
            fila = []
            for j in range(columnas):

                if( j == 0 and i!=0 and i!= filas-1): # Borde izquierdo, no esquinas  
                            pixel_r =  imagen[i-1][j][0]*convolucion[0][1] + imagen[i][j][0]*convolucion[1][1] + imagen[i+1][j][0]*convolucion[2][1]
                            pixel_g =  imagen[i-1][j][1]*convolucion[0][1] + imagen[i][j][1]*convolucion[1][1] + imagen[i+1][j][1]*convolucion[2][1] 
                            pixel_b =  imagen[i-1][j][2]*convolucion[0][1] + imagen[i][j][2]*convolucion[1][1] + imagen[i+1][j][2]*convolucion[2][1] 

                elif( i == 0 and j == 0): # Esquina superior izquierda
                            pixel_r =  imagen[i][j][0]*convolucion[1][1] + imagen[i+1][j][0]*convolucion[2][1]
                            pixel_g =  imagen[i][j][1]*convolucion[1][1] + imagen[i+1][j][1]*convolucion[2][1] 
                            pixel_b =  imagen[i][j][2]*convolucion[1][1] + imagen[i+1][j][2]*convolucion[2][1]
                            fila.append([pixel_r/suma_convolucion, pixel_g/suma_convolucion, pixel_b/suma_convolucion])

                elif( i == filas-1 and j == 0 ): # Esquina inferior izquierda   
                            pixel_r =  imagen[i-1][j][0]*convolucion[0][1] + imagen[i][j][0]*convolucion[1][1] 
                            pixel_g =  imagen[i-1][j][1]*convolucion[0][1] + imagen[i][j][1]*convolucion[1][1]
                            pixel_b =  imagen[i-1][j][2]*convolucion[0][1] + imagen[i][j][2]*convolucion[1][1]
                            fila.append([pixel_r/suma_convolucion, pixel_g/suma_convolucion, pixel_b/suma_convolucion])

            lista.append(fila)

    elif(filas == 1 and columnas == 1):

        pixel_r =  imagen[0][0][0]*convolucion[1][1] 
        pixel_g =  imagen[0][0][1]*convolucion[1][1] 
        pixel_b =  imagen[0][0][2]*convolucion[1][1]
    
        lista.append([[[pixel_r/suma_convolucion, pixel_g/suma_convolucion, pixel_b/suma_convolucion]]])




    return lista 

#M = fabricar_matriz(50,20)
#kernel = [[0,-1,0],[-1,5,-1],[0,-1,0]]
#M_convolucionada = convolucion_imagen(M, kernel)
#print(M)
#print(M_convolucionada)
